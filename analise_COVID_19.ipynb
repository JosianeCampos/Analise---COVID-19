# %% [markdown]
# # Análise de Dados - COVID-19 - Estado de São Paulo

# %% [markdown]
# ## Importando as bibliotecas necessárias inicialmente.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import date

# %% [markdown]
# ## Análise exploratória inicial

# %%
df = pd.read_csv('dados/cases-brazil-states.csv')
df.head(20)
# Out:
#     semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0        9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 1        9  2020-02-25  Brazil  TOTAL  TOTAL            0       0           1
# 2        9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 3        9  2020-02-26  Brazil  TOTAL  TOTAL            0       0           0
# 4        9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 5        9  2020-02-27  Brazil  TOTAL  TOTAL            0       0           0
# 6        9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 7        9  2020-02-28  Brazil  TOTAL  TOTAL            0       0           1
# 8        9  2020-02-29  Brazil     SP  TOTAL            0       0           0
# 9        9  2020-02-29  Brazil  TOTAL  TOTAL            0       0           0
# 10      10  2020-03-01  Brazil     SP  TOTAL            0       0           0
# 11      10  2020-03-01  Brazil  TOTAL  TOTAL            0       0           0
# 12      10  2020-03-02  Brazil     SP  TOTAL            0       0           0
# 13      10  2020-03-02  Brazil  TOTAL  TOTAL            0       0           0
# 14      10  2020-03-03  Brazil     SP  TOTAL            0       0           0
# 15      10  2020-03-03  Brazil  TOTAL  TOTAL            0       0           0
# 16      10  2020-03-04  Brazil     SP  TOTAL            0       0           1
# 17      10  2020-03-04  Brazil  TOTAL  TOTAL            0       0           1
# 18      10  2020-03-05  Brazil     RJ  TOTAL            0       0           1
# 19      10  2020-03-05  Brazil     SP  TOTAL            0       0           3
#
#     Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0       1         0        0              0.0         0.00218
# 1       1         0        0              0.0         0.00048
# 2       1         0        1              0.0         0.00218
# 3       1         0        1              0.0         0.00048
# 4       1         0        1              0.0         0.00218
# 5       1         0        1              0.0         0.00048
# 6       2         0        1              0.0         0.00436
# 7       2         0        1              0.0         0.00095
# 8       2         0        2              0.0         0.00436
# 9       2         0        2              0.0         0.00095
# 10      2         0        2              0.0         0.00436
# 11      2         0        2              0.0         0.00095
# 12      2         0        2              0.0         0.00436
# 13      2         0        2              0.0         0.00095
# 14      2         0        2              0.0         0.00436
# 15      2         0        2              0.0         0.00095
# 16      3         0        3              0.0         0.00653
# 17      3         0        3              0.0         0.00143
# 18      1         0        1              0.0         0.00579
# 19      6         0        6              0.0         0.01307
#
#     obitos_por_casos  recuperados  suspeitos  testes  testes_por_100k
# 0                0.0          NaN        NaN     NaN              NaN
# 1                0.0          NaN        NaN     NaN              NaN
# 2                0.0          NaN        NaN     NaN              NaN
# 3                0.0          NaN        NaN     NaN              NaN
# 4                0.0          NaN        NaN     NaN              NaN
# 5                0.0          NaN        NaN     NaN              NaN
# 6                0.0          NaN        NaN     NaN              NaN
# 7                0.0          NaN        NaN     NaN              NaN
# 8                0.0          NaN        NaN     NaN              NaN
# 9                0.0          NaN        NaN     NaN              NaN
# 10               0.0          NaN        NaN     NaN              NaN
# 11               0.0          NaN        NaN     NaN              NaN
# 12               0.0          NaN        NaN     NaN              NaN
# 13               0.0          NaN        NaN     NaN              NaN
# 14               0.0          NaN        NaN     NaN              NaN
# 15               0.0          NaN        NaN     NaN              NaN
# 16               0.0          NaN        NaN     NaN              NaN
# 17               0.0          NaN        NaN     NaN              NaN
# 18               0.0          NaN        NaN     NaN              NaN
# 19               0.0          NaN        NaN     NaN              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3962 entries, 0 to 3961
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   semana            3962 non-null   int64
#  1   data              3962 non-null   object
#  2   pais              3962 non-null   object
#  3   estado            3962 non-null   object
#  4   cidade            3962 non-null   object
#  5   novosObitos       3962 non-null   int64
#  6   Obitos            3962 non-null   int64
#  7   novosCasos        3962 non-null   int64
#  8   Casos             3962 non-null   int64
#  9   obitosMS          3962 non-null   int64
#  10  casosMS           3962 non-null   int64
#  11  obitos_por_100k   3962 non-null   float64
#  12  casos_por_100k    3962 non-null   float64
#  13  obitos_por_casos  3962 non-null   float64
#  14  recuperados       3240 non-null   float64
#  15  suspeitos         3163 non-null   float64
#  16  testes            2618 non-null   float64
#  17  testes_por_100k   2618 non-null   float64
# dtypes: float64(7), int64(7), object(4)
# memory usage: 557.3+ KB

# %%
df['data'] = pd.to_datetime(df.data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3962 entries, 0 to 3961
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   semana            3962 non-null   int64
#  1   data              3962 non-null   datetime64[ns]
#  2   pais              3962 non-null   object
#  3   estado            3962 non-null   object
#  4   cidade            3962 non-null   object
#  5   novosObitos       3962 non-null   int64
#  6   Obitos            3962 non-null   int64
#  7   novosCasos        3962 non-null   int64
#  8   Casos             3962 non-null   int64
#  9   obitosMS          3962 non-null   int64
#  10  casosMS           3962 non-null   int64
#  11  obitos_por_100k   3962 non-null   float64
#  12  casos_por_100k    3962 non-null   float64
#  13  obitos_por_casos  3962 non-null   float64
#  14  recuperados       3240 non-null   float64
#  15  suspeitos         3163 non-null   float64
#  16  testes            2618 non-null   float64
#  17  testes_por_100k   2618 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(7), object(3)
# memory usage: 557.3+ KB

# %%
plt.figure(figsize = (20,8))
fig = sns.lineplot( x = 'data', y = 'Obitos', hue = 'estado', data = df )
fig.set_title('Óbitos por estado em função do tempo', loc = 'left', fontsize = 26)
fig.set_xlabel('Data', fontsize = 24)
fig.set_ylabel('Óbitos', fontsize = 24)
# Out:
# Text(0, 0.5, 'Óbitos')

# %%
df_sp = df[df.estado == 'SP']

# %%
df_sp
# Out:
#       semana       data    pais estado cidade  novosObitos  Obitos  \
# 0          9 2020-02-25  Brazil     SP  TOTAL            0       0
# 2          9 2020-02-26  Brazil     SP  TOTAL            0       0
# 4          9 2020-02-27  Brazil     SP  TOTAL            0       0
# 6          9 2020-02-28  Brazil     SP  TOTAL            0       0
# 8          9 2020-02-29  Brazil     SP  TOTAL            0       0
# ...      ...        ...     ...    ...    ...          ...     ...
# 3847      31 2020-07-27  Brazil     SP  TOTAL           70   21676
# 3875      31 2020-07-28  Brazil     SP  TOTAL          383   22059
# 3903      31 2020-07-29  Brazil     SP  TOTAL          330   22389
# 3931      31 2020-07-30  Brazil     SP  TOTAL          321   22710
# 3959      31 2020-07-31  Brazil     SP  TOTAL          287   22997
#
#       novosCasos   Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0              1       1         0        0          0.00000         0.00218
# 2              0       1         0        1          0.00000         0.00218
# 4              0       1         0        1          0.00000         0.00218
# 6              1       2         0        1          0.00000         0.00436
# 8              0       2         0        2          0.00000         0.00436
# ...          ...     ...       ...      ...              ...             ...
# 3847        3672  487654     21676   487654         47.20481      1061.98628
# 3875       12647  500301     21676   487654         48.03889      1089.52823
# 3903       13896  514197     22389   514197         48.75754      1119.79018
# 3931       14809  529006     22710   529006         49.45660      1152.04041
# 3959       13298  542304     22997   542304         50.08161      1181.00007
#
#       obitos_por_casos  recuperados  suspeitos     testes  testes_por_100k
# 0              0.00000          NaN        NaN        NaN              NaN
# 2              0.00000          NaN        NaN        NaN              NaN
# 4              0.00000          NaN        NaN        NaN              NaN
# 6              0.00000          NaN        NaN        NaN              NaN
# 8              0.00000          NaN        NaN        NaN              NaN
# ...                ...          ...        ...        ...              ...
# 3847           0.04445     337434.0   333078.0  1158851.0       2523.68249
# 3875           0.04409     337434.0   334977.0  1158851.0       2523.68249
# 3903           0.04354     344501.0   340112.0  1158851.0       2523.68249
# 3931           0.04293     349287.0   340112.0  1788225.0       3894.29886
# 3959           0.04241     351610.0   340112.0  1788225.0       3894.29886
#
# [158 rows x 18 columns]

# %%
plt.figure(figsize = (20,10))
fig = sns.lineplot( x = 'data', y = 'Obitos', hue = 'estado', data = df_sp )
fig.set_title('Óbitos por estado em função do tempo', loc = 'left', fontsize = 26)
fig.set_xlabel('Data', fontsize = 24)
fig.set_ylabel('Óbitos', fontsize = 24)
# Out:
# Text(0, 0.5, 'Óbitos')

# %%
plt.figure(figsize = (20,10))
fig = sns.lineplot( x = 'data', y = 'Obitos', data = df_sp )
fig.set_title('Óbitos por estado em função do tempo', loc = 'left', fontsize = 26)
fig.set_xlabel('Data', fontsize = 24)
fig.set_ylabel('Óbitos', fontsize = 24)
fig.set_yscale('log')

# %% [markdown]
# Podemos notar que os óbitos no estado de São Paulo, estão crescendo exponencialmente.

# %%
df_sp = df_sp.fillna(0)

# %%
df_sp
# Out:
#       semana       data    pais estado cidade  novosObitos  Obitos  \
# 0          9 2020-02-25  Brazil     SP  TOTAL            0       0
# 2          9 2020-02-26  Brazil     SP  TOTAL            0       0
# 4          9 2020-02-27  Brazil     SP  TOTAL            0       0
# 6          9 2020-02-28  Brazil     SP  TOTAL            0       0
# 8          9 2020-02-29  Brazil     SP  TOTAL            0       0
# ...      ...        ...     ...    ...    ...          ...     ...
# 3847      31 2020-07-27  Brazil     SP  TOTAL           70   21676
# 3875      31 2020-07-28  Brazil     SP  TOTAL          383   22059
# 3903      31 2020-07-29  Brazil     SP  TOTAL          330   22389
# 3931      31 2020-07-30  Brazil     SP  TOTAL          321   22710
# 3959      31 2020-07-31  Brazil     SP  TOTAL          287   22997
#
#       novosCasos   Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0              1       1         0        0          0.00000         0.00218
# 2              0       1         0        1          0.00000         0.00218
# 4              0       1         0        1          0.00000         0.00218
# 6              1       2         0        1          0.00000         0.00436
# 8              0       2         0        2          0.00000         0.00436
# ...          ...     ...       ...      ...              ...             ...
# 3847        3672  487654     21676   487654         47.20481      1061.98628
# 3875       12647  500301     21676   487654         48.03889      1089.52823
# 3903       13896  514197     22389   514197         48.75754      1119.79018
# 3931       14809  529006     22710   529006         49.45660      1152.04041
# 3959       13298  542304     22997   542304         50.08161      1181.00007
#
#       obitos_por_casos  recuperados  suspeitos     testes  testes_por_100k
# 0              0.00000          0.0        0.0        0.0          0.00000
# 2              0.00000          0.0        0.0        0.0          0.00000
# 4              0.00000          0.0        0.0        0.0          0.00000
# 6              0.00000          0.0        0.0        0.0          0.00000
# 8              0.00000          0.0        0.0        0.0          0.00000
# ...                ...          ...        ...        ...              ...
# 3847           0.04445     337434.0   333078.0  1158851.0       2523.68249
# 3875           0.04409     337434.0   334977.0  1158851.0       2523.68249
# 3903           0.04354     344501.0   340112.0  1158851.0       2523.68249
# 3931           0.04293     349287.0   340112.0  1788225.0       3894.29886
# 3959           0.04241     351610.0   340112.0  1788225.0       3894.29886
#
# [158 rows x 18 columns]

# %%
plt.figure(figsize = (20,8))
fig = plt.bar(df_sp.data, df_sp.suspeitos, label = 'Suspeitos')
plt.bar(df_sp.data, df_sp.recuperados, label = 'Recuperados')
plt.bar(df_sp.data, df_sp.Obitos, label = 'Óbitos')
plt.xlabel('Data', fontsize = 18)
plt.ylabel('Óbitos, recuperados e suspeitos no estado de SP', fontsize = 18, rotation = 90)
plt.legend()
plt.show()

# %% [markdown]
# Podemos notar que o número de recuperados aumentou subitamente no mês de junho. Fazendo algumas pesquisas podemos entender o por que desse
# aumento repentino: isso ocorreu por que no mês de junho o estado de São Paulo divulgou, pela primeira vez, o número de recuperados que não precisaram de internação hospitalar. Anteriormente, a secretaria estadual da Saúde calculava apenas o total de altas hospitalares entre pacientes internados com Covid-19. Acesse o link para saber mais: https://g1.globo.com/sp/sao-paulo/noticia/2020/07/01/governo-de-sp-divulga-pela-1a-vez-total-de-recuperados-entre-casos-leves-de-covid-19-e-numero-somados-as-altas-hospitalares-vai-a-157-mil.ghtml

# %% [markdown]
# Depois dessa análise exploratória inicial, queremos investigar os Novos Obitos e Novos Casos do estado de São Paulo.
#     Temos uma tendência de aumento nessas variáveis?
#     Temos sazonalidade?

# %% [markdown]
# ## Analisando graficamente os campos novosCasos e novosObitos

# %%
df_sp
# Out:
#       semana       data    pais estado cidade  novosObitos  Obitos  \
# 0          9 2020-02-25  Brazil     SP  TOTAL            0       0
# 2          9 2020-02-26  Brazil     SP  TOTAL            0       0
# 4          9 2020-02-27  Brazil     SP  TOTAL            0       0
# 6          9 2020-02-28  Brazil     SP  TOTAL            0       0
# 8          9 2020-02-29  Brazil     SP  TOTAL            0       0
# ...      ...        ...     ...    ...    ...          ...     ...
# 3847      31 2020-07-27  Brazil     SP  TOTAL           70   21676
# 3875      31 2020-07-28  Brazil     SP  TOTAL          383   22059
# 3903      31 2020-07-29  Brazil     SP  TOTAL          330   22389
# 3931      31 2020-07-30  Brazil     SP  TOTAL          321   22710
# 3959      31 2020-07-31  Brazil     SP  TOTAL          287   22997
#
#       novosCasos   Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0              1       1         0        0          0.00000         0.00218
# 2              0       1         0        1          0.00000         0.00218
# 4              0       1         0        1          0.00000         0.00218
# 6              1       2         0        1          0.00000         0.00436
# 8              0       2         0        2          0.00000         0.00436
# ...          ...     ...       ...      ...              ...             ...
# 3847        3672  487654     21676   487654         47.20481      1061.98628
# 3875       12647  500301     21676   487654         48.03889      1089.52823
# 3903       13896  514197     22389   514197         48.75754      1119.79018
# 3931       14809  529006     22710   529006         49.45660      1152.04041
# 3959       13298  542304     22997   542304         50.08161      1181.00007
#
#       obitos_por_casos  recuperados  suspeitos     testes  testes_por_100k
# 0              0.00000          0.0        0.0        0.0          0.00000
# 2              0.00000          0.0        0.0        0.0          0.00000
# 4              0.00000          0.0        0.0        0.0          0.00000
# 6              0.00000          0.0        0.0        0.0          0.00000
# 8              0.00000          0.0        0.0        0.0          0.00000
# ...                ...          ...        ...        ...              ...
# 3847           0.04445     337434.0   333078.0  1158851.0       2523.68249
# 3875           0.04409     337434.0   334977.0  1158851.0       2523.68249
# 3903           0.04354     344501.0   340112.0  1158851.0       2523.68249
# 3931           0.04293     349287.0   340112.0  1788225.0       3894.29886
# 3959           0.04241     351610.0   340112.0  1788225.0       3894.29886
#
# [158 rows x 18 columns]

# %%
plt.figure(figsize = (20,10))
fig = sns.lineplot( x = 'data', y = 'novosObitos', data = df_sp )
fig.set_title('Novos Óbitos em SP', loc = 'left', fontsize = 26)
fig.set_xlabel('Data', fontsize = 24)
fig.set_ylabel('Óbitos', fontsize = 24)
fig.set_yscale('log')

# %%
plt.figure(figsize = (20,10))
fig = sns.lineplot( x = 'data', y = 'novosCasos', data = df_sp )
fig.set_title('Novos Casos em SP', loc = 'left', fontsize = 26)
fig.set_xlabel('Data', fontsize = 24)
fig.set_ylabel('Casos', fontsize = 24)
fig.set_yscale('log')

# %% [markdown]
# Podemos notar que nos dois gráficos temos a presença de sazonalidade. Será que essa sazonalidade é semanal? Vamos analisar isso?

# %%
df_sp['mes'] = df_sp.data.dt.month

# %%
df_sp
# Out:
#       semana       data    pais estado cidade  novosObitos  Obitos  \
# 0          9 2020-02-25  Brazil     SP  TOTAL            0       0
# 2          9 2020-02-26  Brazil     SP  TOTAL            0       0
# 4          9 2020-02-27  Brazil     SP  TOTAL            0       0
# 6          9 2020-02-28  Brazil     SP  TOTAL            0       0
# 8          9 2020-02-29  Brazil     SP  TOTAL            0       0
# ...      ...        ...     ...    ...    ...          ...     ...
# 3847      31 2020-07-27  Brazil     SP  TOTAL           70   21676
# 3875      31 2020-07-28  Brazil     SP  TOTAL          383   22059
# 3903      31 2020-07-29  Brazil     SP  TOTAL          330   22389
# 3931      31 2020-07-30  Brazil     SP  TOTAL          321   22710
# 3959      31 2020-07-31  Brazil     SP  TOTAL          287   22997
#
#       novosCasos   Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0              1       1         0        0          0.00000         0.00218
# 2              0       1         0        1          0.00000         0.00218
# 4              0       1         0        1          0.00000         0.00218
# 6              1       2         0        1          0.00000         0.00436
# 8              0       2         0        2          0.00000         0.00436
# ...          ...     ...       ...      ...              ...             ...
# 3847        3672  487654     21676   487654         47.20481      1061.98628
# 3875       12647  500301     21676   487654         48.03889      1089.52823
# 3903       13896  514197     22389   514197         48.75754      1119.79018
# 3931       14809  529006     22710   529006         49.45660      1152.04041
# 3959       13298  542304     22997   542304         50.08161      1181.00007
#
#       obitos_por_casos  recuperados  suspeitos     testes  testes_por_100k  \
# 0              0.00000          0.0        0.0        0.0          0.00000
# 2              0.00000          0.0        0.0        0.0          0.00000
# 4              0.00000          0.0        0.0        0.0          0.00000
# 6              0.00000          0.0        0.0        0.0          0.00000
# 8              0.00000          0.0        0.0        0.0          0.00000
# ...                ...          ...        ...        ...              ...
# 3847           0.04445     337434.0   333078.0  1158851.0       2523.68249
# 3875           0.04409     337434.0   334977.0  1158851.0       2523.68249
# 3903           0.04354     344501.0   340112.0  1158851.0       2523.68249
# 3931           0.04293     349287.0   340112.0  1788225.0       3894.29886
# 3959           0.04241     351610.0   340112.0  1788225.0       3894.29886
#
#       mes
# 0       2
# 2       2
# 4       2
# 6       2
# 8       2
# ...   ...
# 3847    7
# 3875    7
# 3903    7
# 3931    7
# 3959    7
#
# [158 rows x 19 columns]

# %%
fig, axes = plt.subplots(2, 3, sharex=True, figsize=(28,18))
fig.suptitle('Análise mensal de Novos Casos e Novos Óbitos', fontsize = (30))
sns.lineplot(ax=axes[0,0], x = 'data', y = 'novosCasos', data = df_sp[df_sp.mes == 4] )
sns.lineplot(ax=axes[0,1], x = 'data', y = 'novosCasos', data = df_sp[df_sp.mes == 5] )
sns.lineplot(ax=axes[0,2] ,x = 'data', y = 'novosCasos', data = df_sp[df_sp.mes == 6] )
sns.lineplot( ax=axes[1,0],x = 'data', y = 'novosObitos', data = df_sp[df_sp.mes == 4] )
sns.lineplot( ax=axes[1,1],x = 'data', y = 'novosObitos', data = df_sp[df_sp.mes == 5] )
sns.lineplot( ax=axes[1,2],x = 'data', y = 'novosObitos', data = df_sp[df_sp.mes == 6] )
axes[0,0].set_title('Novos Casos no mês de abril', fontsize = 25)
axes[0,1].set_title('Novos Casos no mês de maio', fontsize = 25)
axes[0,2].set_title('Novos Casos no mês de junho', fontsize = 25)
axes[1,0].set_title('Novos Óbitos no mês de abril', fontsize = 25)
axes[1,1].set_title('Novos Óbitos no mês de maio', fontsize = 25)
axes[1,2].set_title('Novos Óbitos no mês de junho', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Novos Óbitos no mês de junho')

# %%
df_sp['dia_da_semana']= df_sp.data.dt.strftime('%A')

# %%
grupo = df_sp.groupby('dia_da_semana')['novosObitos','novosCasos'].mean()
grupo
# Out:
# C:\Users\Josiane\AppData\Local\Temp\ipykernel_292\1285402799.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grupo = df_sp.groupby('dia_da_semana')['novosObitos','novosCasos'].mean()
#                novosObitos   novosCasos
# dia_da_semana
# Friday          177.173913  4691.956522
# Monday           40.590909  1286.045455
# Saturday        155.227273  3282.681818
# Sunday           60.409091  2113.409091
# Thursday        190.000000  4374.000000
# Tuesday         206.391304  3902.000000
# Wednesday       181.217391  4218.869565

# %%
grupo = grupo.reindex(['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])

# %%
area = plt.figure(figsize = (18,12))
g1 = area.add_subplot(1,2,1)
g2 = area.add_subplot(1,2,2)
g1.bar(grupo.index, grupo.novosObitos)
g1.set_title('Média dos Novos Óbitos durante a semana')
g2.bar(grupo.index, grupo.novosCasos)
g2.set_title('Média dos Novos Casos durante a semana')
# Out:
# Text(0.5, 1.0, 'Média dos Novos Casos durante a semana')

# %% [markdown]
# Com os gráficos acima podemos observar que a sazonalidade ocorre semanalmente. Essa sazonalidade ocorre pois a maior parte dos dados são lançados
# ao sistema durante a semana, tendo uma queda de lançamento no domingo e na segunda, devido aos plantões médicos.

# %% [markdown]
# ## Tendencia
